# %%
# Importo el módulo matplotlib.pyplot y le doy un alias para la realizacion de gráficos
import matplotlib.pyplot as plt

# %%
# Uso este truco para que me muestre los gráficos en el entorno de programacioón
# %matplotlib inline

# %%
# Importo el módulo numpy y le doy un alias para usar sus métodos en el código
import numpy as np

plt.figure(figsize=(10, 8))            # Uso de la función figure para agrandar el gráfico


# Código para pasarle los datos al gráfico
n = 256

X = np.linspace(-np.pi, np.pi, n, endpoint=True)

Y = np.sin(2 * X) 

# Gráfico con las intrucciones pedidas por el profesor
plt.plot(X, Y + 1, color='blue', alpha=1.00)

plt.fill_between(X, 1, Y + 1, color='blue', alpha=.25)

plt.plot(X, Y - 1, color='blue', alpha=1.00)

plt.fill_between(X, -1, Y - 1, (Y - 1) > -1 , color = "blue", alpha = .25)

plt.fill_between(X, -1, Y - 1, (Y - 1) < -1, color = "red", alpha = .25)

plt.xlim(-np.pi, np.pi)

plt.ylim(-2.5, 2.5)

plt.xticks(())

plt.yticks(())


                 
plt.show()

# %%
n = 1024

X = np.random.normal(0, 1, n)

Y = np.random.normal(0, 1, n)

T = np.arctan2(Y, X)



plt.axes([0.025, 0.025, 0.95, 0.95])

plt.scatter(X, Y, s=75, c=T, alpha=.5)



plt.xlim(-1.5, 1.5)

plt.xticks(())

plt.ylim(-1.5, 1.5)

plt.yticks(())

plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt


# Datos para el gráfico
n = 12

X = np.arange(n)

Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)

Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)


# Creación del gráfico con las intrucciones dichas por el profesor
plt.axes([0.025, 0.025, 0.95, 0.95])

plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')

plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')



for x, y in zip(X, Y1):

    plt.text(x + 0.5, y + 0.05, '%.2f' % y, ha='center', va= 'bottom')



for x, y in zip(X, Y2):

    plt.text(x + 0.5, -y - 0.05, '%.2f' % y, ha='center', va= 'top')



plt.xlim(-.5, n)

plt.xticks(())

plt.ylim(-1.25, 1.25)

plt.yticks(())



plt.show()

# %%
from matplotlib import colors, cm


Z = np.random.uniform(0, 1, 20)

# Creo variables para hacer un mapeo de colores
normdata = colors.Normalize(min(Z), max(Z))
colormap = cm.get_cmap("Dark2")
colores = colormap(normdata(Z))

# Uso de la función pie para hacer un gráfico circular
plt.pie(Z, colors = colores)

# Uso de la función axis para que el gráfico no este tan achatado
plt.axis("equal")

plt.show()

# %%
x = ["Fran", "Maga", "Nico", "Papi"]
y = [100, 60, 70 , 10]

plt.bar(x, y, color = ["red","blue","black","green"], width = 0.6, edgecolor = "yellow")

plt.ylabel("Porcentaje")
plt.xlabel("Alumnos")
plt.title("Notas con sus porcentajes de los alumnos de ingenieria", color = "red", fontsize = 13)
# Out:
# Text(0.5, 1.0, 'Notas con sus porcentajes de los alumnos de ingenieria')
